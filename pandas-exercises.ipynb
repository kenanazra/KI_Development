# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. The solutions are available in a solutions notebook, however, you should always try to figure them out yourself first.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Exercises are based off (and directly taken from) the quick introduction to pandas notebook.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colours =pd.Series(['red','blue','black'])

# %%
# View the series of different colours
colours
# Out:
# 0      red
# 1     blue
# 2    black
# dtype: object

# %%
# Create a series of three different car types and view it
car = pd.Series(['VW','BMW','Z'])
car
# Out:
# 0     VW
# 1    BMW
# 2      Z
# dtype: object

# %%
car_colour = pd.DataFrame({'car':car,'colour':colours})
car_colour
# Out:
#    car colour
# 0   VW    red
# 1  BMW   blue
# 2    Z  black

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
data = pd.read_csv('car-sales.csv')
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
car_colour.to_csv('data_car.csv')

# %%
# Find the different datatypes of the car data DataFrame
car_colour.dtypes
# Out:
# car       object
# colour    object
# dtype: object

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
car_colour.describe()
# Out:
#        car colour
# count    3      3
# unique   3      3
# top     VW    red
# freq     1      1

# %%
# Get information about your DataFrame using info()
car_colour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   car     3 non-null      object
#  1   colour  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %% [markdown]
# What does it show you?

# %%
# Create a Series of different numbers and find the mean of them
number_series = pd.Series([1,2,3,4,5])
number_series.mean()
# Out:
# 3.0

# %%
# Create a Series of different numbers and find the sum of them
number_series = pd.Series([11,12,13,14,15])
number_series.sum()
# Out:
# 65

# %%
# List out all the column names of the car sales DataFrame
data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(data)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
data.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
data.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
data.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
data.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
data.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
data_km = data['Odometer (KM)']
data_km
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
data_km.mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
data[data_km>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
data_crostab = pd.crosstab(data['Make'],data['Doors'])
data_crostab
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
data[data['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df = pd.DataFrame(data)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
#data.groupby(['Make']).mean()
#data

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(df['Odometer (KM)'])
plt.show()

# %%
# Create a histogram of the Odometer column using hist()
plt.hist(df['Odometer (KM)'])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <BarContainer object of 10 artists>)

# %%
# Try to plot the Price column using plot()
plt.plot(df['Price'])

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %%
# Remove the punctuation from price column
#import string
df['Price'] = df['Price'].str.replace('[$,]', '', regex=True)

# %%
# Check the changes to the price column
df['Price']
# Out:
# 0     4000.00
# 1     5000.00
# 2     7000.00
# 3    22000.00
# 4     3500.00
# 5     4500.00
# 6     7500.00
# 7     7000.00
# 8     6250.00
# 9     9700.00
# Name: Price, dtype: object

# %%
# Remove the two extra zeros at the end of the price column
df['Price'] = df['Price'].str.replace('.00$', '', regex=True)

# %%
# Check the changes to the Price column
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
# Change the datatype of the Price column to integers
df['Price'] = df['Price'].astype(int)
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Lower the strings of the Make column
df['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
df['Make'] = df['Make'].str.lower()

# %%
# Check the car sales DataFrame
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")

data_1 = pd.read_csv('car-sales-extended-missing-data.csv')
# Check out the new DataFrame
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
# Fill the Odometer column missing values with the mean of the column inplace
data_1['Odometer (KM)'] = data_1['Odometer (KM)'].fillna(data_1['Odometer (KM)'].mean())

# %%
# View the car sales missing DataFrame and verify the changes
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  1000 non-null   float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
# Remove the rest of the missing data inplace
data_1.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
data_1['Seats'] =5
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
# Create a column called " " with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import numpy as np
data_1['rand'] = np.random.uniform(1.3,4.5,len(data_1))
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats      rand
# 0     Honda  White        35431.0    4.0  15323.0      5  2.349080
# 1       BMW   Blue       192714.0    5.0  19943.0      5  2.159975
# 2     Honda  White        84714.0    4.0  28343.0      5  2.864891
# 3    Toyota  White       154365.0    4.0  13434.0      5  2.207391
# 4    Nissan   Blue       181577.0    3.0  14043.0      5  1.696332
# ..      ...    ...            ...    ...      ...    ...       ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5  4.271440
# 995  Toyota  Black        35820.0    4.0  32042.0      5  3.858226
# 997  Nissan   Blue        66604.0    4.0  31570.0      5  2.821078
# 998   Honda  White       215883.0    4.0   4001.0      5  2.003801
# 999  Toyota   Blue       248360.0    4.0  12732.0      5  4.496748
#
# [815 rows x 7 columns]

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
data_1['price/km'] = data_1['Price']/data_1['Odometer (KM)']
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats      rand  price/km
# 0     Honda  White        35431.0    4.0  15323.0      5  2.349080  0.432474
# 1       BMW   Blue       192714.0    5.0  19943.0      5  2.159975  0.103485
# 2     Honda  White        84714.0    4.0  28343.0      5  2.864891  0.334573
# 3    Toyota  White       154365.0    4.0  13434.0      5  2.207391  0.087027
# 4    Nissan   Blue       181577.0    3.0  14043.0      5  1.696332  0.077339
# ..      ...    ...            ...    ...      ...    ...       ...       ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5  4.271440  0.193887
# 995  Toyota  Black        35820.0    4.0  32042.0      5  3.858226  0.894528
# 997  Nissan   Blue        66604.0    4.0  31570.0      5  2.821078  0.473996
# 998   Honda  White       215883.0    4.0   4001.0      5  2.003801  0.018533
# 999  Toyota   Blue       248360.0    4.0  12732.0      5  4.496748  0.051264
#
# [815 rows x 8 columns]

# %%
# Remove the last column you added using .drop()
data_1 = data_1.drop(columns='price/km')

# %%
data_1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats      rand
# 0     Honda  White        35431.0    4.0  15323.0      5  2.349080
# 1       BMW   Blue       192714.0    5.0  19943.0      5  2.159975
# 2     Honda  White        84714.0    4.0  28343.0      5  2.864891
# 3    Toyota  White       154365.0    4.0  13434.0      5  2.207391
# 4    Nissan   Blue       181577.0    3.0  14043.0      5  1.696332
# ..      ...    ...            ...    ...      ...    ...       ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5  4.271440
# 995  Toyota  Black        35820.0    4.0  32042.0      5  3.858226
# 997  Nissan   Blue        66604.0    4.0  31570.0      5  2.821078
# 998   Honda  White       215883.0    4.0   4001.0      5  2.003801
# 999  Toyota   Blue       248360.0    4.0  12732.0      5  4.496748
#
# [815 rows x 7 columns]

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable

# DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)[source]
data_1_Sampled = data_1.sample(frac=0.1)
data_1_Sampled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats      rand
# 752  Toyota   Blue       240627.0    4.0   5285.0      5  2.382270
# 893  Toyota  White       248815.0    4.0   9785.0      5  1.562638
# 477  Toyota   Blue       119311.0    4.0  26816.0      5  4.474055
# 142   Honda  White        21393.0    4.0  20490.0      5  2.877454
# 890  Toyota  Black       144944.0    4.0  22873.0      5  2.073085
# ..      ...    ...            ...    ...      ...    ...       ...
# 42    Honda  Black       200490.0    4.0   6337.0      5  4.210038
# 50   Toyota    Red       184878.0    4.0   7445.0      5  2.227003
# 602   Honda   Blue        40912.0    4.0  26885.0      5  2.214756
# 807  Toyota  Green        88519.0    4.0  18640.0      5  2.580497
# 300  Nissan  White       234161.0    4.0  13200.0      5  2.971456
#
# [82 rows x 7 columns]

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
data_1_Sampled.reset_index()
# Out:
#     index    Make Colour  Odometer (KM)  Doors    Price  Seats      rand
# 0     752  Toyota   Blue       240627.0    4.0   5285.0      5  2.382270
# 1     893  Toyota  White       248815.0    4.0   9785.0      5  1.562638
# 2     477  Toyota   Blue       119311.0    4.0  26816.0      5  4.474055
# 3     142   Honda  White        21393.0    4.0  20490.0      5  2.877454
# 4     890  Toyota  Black       144944.0    4.0  22873.0      5  2.073085
# ..    ...     ...    ...            ...    ...      ...    ...       ...
# 77     42   Honda  Black       200490.0    4.0   6337.0      5  4.210038
# 78     50  Toyota    Red       184878.0    4.0   7445.0      5  2.227003
# 79    602   Honda   Blue        40912.0    4.0  26885.0      5  2.214756
# 80    807  Toyota  Green        88519.0    4.0  18640.0      5  2.580497
# 81    300  Nissan  White       234161.0    4.0  13200.0      5  2.971456
#
# [82 rows x 8 columns]

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
data_1_Sampled['Odometer (KM)'] = data_1_Sampled['Odometer (KM)']*0.621371

# %%
data_1_Sampled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats      rand
# 752  Toyota   Blue  149518.639617    4.0   5285.0      5  2.382270
# 893  Toyota  White  154606.425365    4.0   9785.0      5  1.562638
# 477  Toyota   Blue   74136.395381    4.0  26816.0      5  4.474055
# 142   Honda  White   13292.989803    4.0  20490.0      5  2.877454
# 890  Toyota  Black   90063.998224    4.0  22873.0      5  2.073085
# ..      ...    ...            ...    ...      ...    ...       ...
# 42    Honda  Black  124578.671790    4.0   6337.0      5  4.210038
# 50   Toyota    Red  114877.827738    4.0   7445.0      5  2.227003
# 602   Honda   Blue   25421.530352    4.0  26885.0      5  2.214756
# 807  Toyota  Green   55003.139549    4.0  18640.0      5  2.580497
# 300  Nissan  White  145500.854731    4.0  13200.0      5  2.971456
#
# [82 rows x 7 columns]

# %%
# Change the title of the Odometer (KM) to represent data_1_Sampled.he instead of kilometers
data_1_Sampled.columns
data_1_Sampled.rename(columns={'Odometer (KM)':'Odometer (miles)'})
# Out:
#        Make Colour  Odometer (miles)  Doors    Price  Seats      rand
# 752  Toyota   Blue     149518.639617    4.0   5285.0      5  2.382270
# 893  Toyota  White     154606.425365    4.0   9785.0      5  1.562638
# 477  Toyota   Blue      74136.395381    4.0  26816.0      5  4.474055
# 142   Honda  White      13292.989803    4.0  20490.0      5  2.877454
# 890  Toyota  Black      90063.998224    4.0  22873.0      5  2.073085
# ..      ...    ...               ...    ...      ...    ...       ...
# 42    Honda  Black     124578.671790    4.0   6337.0      5  4.210038
# 50   Toyota    Red     114877.827738    4.0   7445.0      5  2.227003
# 602   Honda   Blue      25421.530352    4.0  26885.0      5  2.214756
# 807  Toyota  Green      55003.139549    4.0  18640.0      5  2.580497
# 300  Nissan  White     145500.854731    4.0  13200.0      5  2.971456
#
# [82 rows x 7 columns]

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the pandas documentation, particularly the [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html).
#
# One great exercise would be to retype out the entire section into a Jupyter Notebook of your own.
#
# Get hands-on with the code and see what it does.
#
# The next place you should check out are the [top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true). Often, these contain some of the most useful and common pandas functions. Be sure to play around with the different filters!
#
# Finally, always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
