# %% [markdown]
# # Welcome!

# %% [markdown]
# #### Pandas: Intro Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll be practicing these programming concepts we've covered in class:
# * Reading data sets into Pandas.
# * Filtering, manipulating, and sorting data sets.
# * Basic exploratory data analysis with Pandas.

# %% [markdown]
# #### #1. Import Pandas with an alias of `pd`.

# %%
import pandas as pd

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df = pd.read_csv('NBA_players_2015.csv')
nba_df
# Out:
#      Unnamed: 0  season_end          player pos  age bref_team_id   g  gs  \
# 0             0        2015      Quincy Acy   F   24          NYK  52  21
# 1             1        2015    Jordan Adams   G   20          MEM  18   0
# 2             2        2015    Steven Adams   C   21          OKC  51  50
# 3             3        2015     Jeff Adrien   F   28          MIN  17   0
# 4             4        2015   Arron Afflalo   G   29          TOT  60  54
# ..          ...         ...             ...  ..  ...          ...  ..  ..
# 473         473        2015     James Young   G   19          BOS  27   0
# 474         474        2015      Nick Young   G   29          LAL  42   0
# 475         475        2015  Thaddeus Young   F   26          TOT  58  50
# 476         476        2015     Cody Zeller   C   22          CHO  61  44
# 477         477        2015    Tyler Zeller   C   25          BOS  62  39
#
#        mp   fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0    19.2  2.2  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     7.3  1.0  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2    24.2  3.0  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3    12.6  1.1  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    32.5  5.0  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473  10.9  1.1  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  23.8  4.1  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  31.8  5.9  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476  24.1  2.8  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477  20.8  3.9  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 50 columns]

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
nba_df.head(5)
# Out:
#    Unnamed: 0  season_end         player pos  age bref_team_id   g  gs    mp  \
# 0           0        2015     Quincy Acy   F   24          NYK  52  21  19.2
# 1           1        2015   Jordan Adams   G   20          MEM  18   0   7.3
# 2           2        2015   Steven Adams   C   21          OKC  51  50  24.2
# 3           3        2015    Jeff Adrien   F   28          MIN  17   0  12.6
# 4           4        2015  Arron Afflalo   G   29          TOT  60  54  32.5
#
#     fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  2.2  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  1.0  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  3.0  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  1.1  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  5.0  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 50 columns]

# %% [markdown]
# #### #4. Check out the shape of the data set.

# %%
nba_df.shape
# Out:
# (478, 50)

# %% [markdown]
# #### #5. Run some summary stats on the data set with the `describe()` function.

# %%
nba_df.describe()
# Out:
#        Unnamed: 0  season_end         age           g          gs          mp  \
# count  478.000000       478.0  478.000000  478.000000  478.000000  478.000000
# mean   238.500000      2015.0   26.573222   42.104603   19.874477   20.045607
# std    138.130976         0.0    4.219585   18.950602   22.170034    9.313441
# min      0.000000      2015.0   19.000000    1.000000    0.000000    0.700000
# 25%    119.250000      2015.0   23.000000   27.000000    0.000000   12.600000
# 50%    238.500000      2015.0   26.000000   47.000000   10.500000   19.850000
# 75%    357.750000      2015.0   29.000000   59.000000   39.000000   28.175000
# max    477.000000      2015.0   38.000000   66.000000   66.000000   38.900000
#
#                fg         fga         fg_         x3p  ...        TOV%  \
# count  478.000000  478.000000  478.000000  478.000000  ...  478.000000
# mean     3.018201    6.847699    0.429230    0.630544  ...   13.424268
# std      2.052790    4.386828    0.111007    0.665808  ...    6.559989
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      1.425000    3.400000    0.391000    0.000000  ...   10.000000
# 50%      2.700000    5.900000    0.432000    0.450000  ...   12.900000
# 75%      4.275000    9.600000    0.481750    1.000000  ...   15.900000
# max      9.500000   21.400000    1.000000    3.400000  ...  100.000000
#
#              USG%         OWS         DWS          WS       WS/48        OBPM  \
# count  478.000000  478.000000  478.000000  478.000000  478.000000  478.000000
# mean    18.915272    1.055858    0.971339    2.027197    0.073575   -1.396862
# std      5.493491    1.589667    0.876932    2.243138    0.133530    4.251216
# min      0.000000   -2.100000   -0.100000   -0.800000   -1.059000  -36.800000
# 25%     14.800000    0.000000    0.200000    0.300000    0.040250   -2.800000
# 50%     18.400000    0.600000    0.800000    1.400000    0.082500   -1.000000
# 75%     21.900000    1.600000    1.500000    3.000000    0.123000    0.500000
# max     45.900000    9.500000    4.300000   13.000000    1.489000   28.300000
#
#              DBPM         BPM        VORP
# count  478.000000  478.000000  478.000000
# mean    -0.495816   -1.892678    0.485983
# std      2.299572    5.116001    1.013097
# min    -13.500000  -50.300000   -1.000000
# 25%     -1.600000   -3.300000   -0.100000
# 50%     -0.500000   -1.300000    0.100000
# 75%      0.875000    0.500000    0.700000
# max      6.500000   15.100000    6.200000
#
# [8 rows x 47 columns]

# %% [markdown]
# #### #6. Sort the data set in on the `players` column in alphabetical order.

# %%
nba_sort = nba_df.sort_values('player')
nba_sort
# Out:
#      Unnamed: 0  season_end         player pos  age bref_team_id   g  gs  \
# 359         359        2015     A.J. Price   G   28          TOT  21   0
# 60           60        2015   Aaron Brooks   G   30          CHI  65   9
# 166         166        2015   Aaron Gordon   F   19          ORL  30   6
# 348         348        2015  Adreian Payne   F   23          TOT  12   3
# 212         212        2015     Al Horford   C   28          ATL  60  60
# ..          ...         ...            ...  ..  ...          ...  ..  ..
# 199         199        2015   Xavier Henry   F   23          LAL   9   0
# 261         261        2015    Zach LaVine   G   19          MIN  57  23
# 366         366        2015  Zach Randolph   F   33          MEM  53  53
# 340         340        2015  Zaza Pachulia   C   30          MIL  54  26
# 125         125        2015   Zoran Dragic   G   25          TOT   8   0
#
#        mp   fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 359  13.3  2.3  ...   8.9  23.6  0.2  0.2  0.4  0.072   0.5  -2.8 -2.4   0.0
# 60   21.0  3.9  ...  15.5  25.7  1.1  1.0  2.1  0.073   0.7  -2.8 -2.1   0.0
# 166  15.2  1.9  ...  17.0  15.9  0.3  0.3  0.6  0.066  -2.5  -0.5 -3.1  -0.1
# 348  19.7  2.3  ...  13.6  17.7 -0.3  0.1 -0.1 -0.024  -5.8  -2.5 -8.3  -0.4
# 212  30.8  6.8  ...   9.1  22.1  4.6  3.0  7.5  0.195   1.7   2.7  4.5   3.0
# ..    ...  ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 199   9.6  0.3  ...  11.3  13.7 -0.1  0.0 -0.1 -0.030  -5.3  -2.3 -7.6  -0.1
# 261  20.4  2.9  ...  21.3  20.6 -0.9  0.2 -0.7 -0.029  -2.9  -2.2 -5.0  -0.9
# 366  32.6  6.6  ...  12.4  24.5  2.6  2.9  5.5  0.153   0.2   0.8  1.0   1.3
# 340  22.5  2.9  ...  18.7  18.9  0.1  2.0  2.1  0.084  -2.2   2.0 -0.2   0.6
# 125   2.3  0.3  ...   0.0  22.6  0.0  0.0  0.0 -0.056  -1.9  -5.3 -7.2   0.0
#
# [478 rows x 50 columns]

# %% [markdown]
# #### #7. Filter the data set. Create three sub DataFrames from the `position` column for `G`, `F`, and `C`.

# %%
nba_group = nba_sort.value_counts('pos')
nba_group
# Out:
# pos
# G    200
# F    199
# C     79
# Name: count, dtype: int64

# %%
nba_df_G = nba_sort[nba_sort['pos'] == 'G']
nba_df_G
# Out:
#      Unnamed: 0  season_end         player pos  age bref_team_id   g  gs  \
# 359         359        2015     A.J. Price   G   28          TOT  21   0
# 60           60        2015   Aaron Brooks   G   30          CHI  65   9
# 14           14        2015  Alan Anderson   G   32          BRK  62  19
# 68           68        2015     Alec Burks   G   23          UTA  27  27
# 394         394        2015   Alexey Shved   G   26          TOT  35   2
# ..          ...         ...            ...  ..  ...          ...  ..  ..
# 34           34        2015    Will Barton   G   24          TOT  40   0
# 85           85        2015    Will Cherry   G   23          CLE   8   0
# 179         179        2015   Willie Green   G   33          ORL  42   2
# 261         261        2015    Zach LaVine   G   19          MIN  57  23
# 125         125        2015   Zoran Dragic   G   25          TOT   8   0
#
#        mp   fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 359  13.3  2.3  ...   8.9  23.6  0.2  0.2  0.4  0.072   0.5  -2.8 -2.4   0.0
# 60   21.0  3.9  ...  15.5  25.7  1.1  1.0  2.1  0.073   0.7  -2.8 -2.1   0.0
# 14   23.8  2.5  ...  11.8  13.7  1.3  0.9  2.1  0.070  -0.2  -0.3 -0.5   0.6
# 68   33.3  4.5  ...  12.7  20.9  1.1  0.5  1.5  0.082  -0.3  -1.3 -1.6   0.1
# 394  15.7  2.7  ...  10.1  25.8  1.4  0.3  1.7  0.149   3.1  -3.3 -0.3   0.2
# ..    ...  ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 34   14.2  2.2  ...  12.1  19.9  0.1  0.7  0.8  0.067  -2.0   0.6 -1.4   0.1
# 85    8.6  0.6  ...  15.6  16.7 -0.1  0.1  0.0 -0.022  -4.4   0.7 -3.7   0.0
# 179  17.8  2.2  ...  12.9  17.6 -0.3  0.3  0.0 -0.003  -2.8  -2.2 -5.0  -0.6
# 261  20.4  2.9  ...  21.3  20.6 -0.9  0.2 -0.7 -0.029  -2.9  -2.2 -5.0  -0.9
# 125   2.3  0.3  ...   0.0  22.6  0.0  0.0  0.0 -0.056  -1.9  -5.3 -7.2   0.0
#
# [200 rows x 50 columns]

# %%
nba_df_F = nba_sort[nba_sort['pos'] == 'F']
nba_df_F
# Out:
#      Unnamed: 0  season_end             player pos  age bref_team_id   g  gs  \
# 166         166        2015       Aaron Gordon   F   19          ORL  30   6
# 348         348        2015      Adreian Payne   F   23          TOT  12   3
# 11           11        2015    Al-Farouq Aminu   F   24          DAL  60   3
# 160         160        2015         Alonzo Gee   F   27          TOT  43   0
# 413         413        2015  Amar'e Stoudemire   F   32          TOT  44  14
# ..          ...         ...                ...  ..  ...          ...  ..  ..
# 89           89        2015      Victor Claver   F   26          POR  10   0
# 238         238        2015     Wesley Johnson   F   27          LAL  59  42
# 84           84        2015    Wilson Chandler   F   27          DEN  61  58
# 199         199        2015       Xavier Henry   F   23          LAL   9   0
# 366         366        2015      Zach Randolph   F   33          MEM  53  53
#
#        mp   fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 166  15.2  1.9  ...  17.0  15.9  0.3  0.3  0.6  0.066  -2.5  -0.5 -3.1  -0.1
# 348  19.7  2.3  ...  13.6  17.7 -0.3  0.1 -0.1 -0.024  -5.8  -2.5 -8.3  -0.4
# 11   17.0  2.0  ...  11.8  15.7  0.9  1.7  2.6  0.124  -0.6   3.0  2.3   1.1
# 160  12.4  1.6  ...  14.0  16.3  0.6  0.5  1.1  0.100  -0.8   0.5 -0.3   0.2
# 413  22.8  4.7  ...  14.0  23.2  2.0  0.8  2.8  0.134  -0.2  -0.7 -0.9   0.3
# ..    ...  ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 89    7.6  0.9  ...  16.7  14.1  0.0  0.1  0.1  0.092  -3.0  -1.1 -4.1   0.0
# 238  28.8  3.6  ...  10.3  15.8  1.4  0.5  1.9  0.055  -0.1  -0.4 -0.6   0.6
# 84   31.5  5.4  ...  10.0  20.4  1.2  1.3  2.5  0.062   0.2  -0.5 -0.2   0.9
# 199   9.6  0.3  ...  11.3  13.7 -0.1  0.0 -0.1 -0.030  -5.3  -2.3 -7.6  -0.1
# 366  32.6  6.6  ...  12.4  24.5  2.6  2.9  5.5  0.153   0.2   0.8  1.0   1.3
#
# [199 rows x 50 columns]

# %%
nba_df_C = nba_sort[nba_sort['pos'] == 'C']
nba_df_C
# Out:
#      Unnamed: 0  season_end          player pos  age bref_team_id   g  gs  \
# 212         212        2015      Al Horford   C   28          ATL  60  60
# 225         225        2015    Al Jefferson   C   30          CHO  53  49
# 252         252        2015       Alex Kirk   C   23          CLE   5   0
# 267         267        2015        Alex Len   C   21          PHO  61  36
# 5             5        2015   Alexis Ajinca   C   26          NOP  51   6
# ..          ...         ...             ...  ..  ...          ...  ..  ..
# 407         407        2015  Tiago Splitter   C   30          SAS  39  22
# 322         322        2015  Timofey Mozgov   C   28          TOT  65  64
# 477         477        2015    Tyler Zeller   C   25          BOS  62  39
# 83           83        2015  Tyson Chandler   C   32          DAL  60  60
# 340         340        2015   Zaza Pachulia   C   30          MIL  54  26
#
#        mp   fg  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 212  30.8  6.8  ...   9.1  22.1  4.6  3.0  7.5  0.195   1.7   2.7  4.5   3.0
# 225  31.4  7.8  ...   5.4  26.4  1.5  2.9  4.5  0.129  -0.9   1.7  0.8   1.2
# 252   2.8  0.2  ...   0.0  15.7  0.0  0.0  0.0  0.060  -3.0  -4.3 -7.3   0.0
# 267  21.7  2.7  ...  15.4  13.7  1.5  1.8  3.3  0.119  -2.8   2.0 -0.8   0.4
# 5    14.0  2.8  ...  15.3  20.8  1.8  0.9  2.7  0.181   0.4   0.2  0.7   0.5
# ..    ...  ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 407  19.2  2.8  ...  13.7  17.3  1.4  1.2  2.6  0.168   0.0   2.4  2.4   0.8
# 322  25.7  3.8  ...  14.2  16.2  2.9  1.9  4.8  0.137  -1.4   1.1 -0.3   0.7
# 477  20.8  3.9  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
# 83   30.7  4.0  ...  16.0  12.8  6.1  2.6  8.7  0.226   2.1   2.4  4.4   3.0
# 340  22.5  2.9  ...  18.7  18.9  0.1  2.0  2.1  0.084  -2.2   2.0 -0.2   0.6
#
# [79 rows x 50 columns]

# %% [markdown]
# #### #8.  Run `describe()` on these new DataFrames. Compare the mean field goals (the `fg` column) between positions.

# %%
nba_df_G.describe()
nba_df_F.describe()
nba_df_C.describe()
# Out:
#        Unnamed: 0  season_end        age          g         gs         mp  \
# count   79.000000        79.0  79.000000  79.000000  79.000000  79.000000
# mean   236.240506      2015.0  26.759494  42.012658  23.620253  19.126582
# std    136.163007         0.0   3.810294  19.005056  22.214747   8.937629
# min      2.000000      2015.0  20.000000   2.000000   0.000000   2.800000
# 25%    134.000000      2015.0  24.000000  29.500000   2.500000  12.700000
# 50%    244.000000      2015.0  26.000000  46.000000  18.000000  19.200000
# 75%    345.000000      2015.0  29.500000  58.500000  43.500000  25.900000
# max    477.000000      2015.0  37.000000  65.000000  64.000000  35.400000
#
#               fg        fga        fg_        x3p  ...       TOV%       USG%  \
# count  79.000000  79.000000  79.000000  79.000000  ...  79.000000  79.000000
# mean    2.989873   5.922785   0.495608   0.058228  ...  15.159494  17.755696
# std     2.060595   4.075409   0.120526   0.211592  ...   5.933035   5.592709
# min     0.000000   0.000000   0.000000   0.000000  ...   0.000000   0.000000
# 25%     1.500000   2.850000   0.460500   0.000000  ...  12.150000  13.650000
# 50%     2.800000   5.300000   0.505000   0.000000  ...  15.300000  17.900000
# 75%     4.100000   7.600000   0.551000   0.000000  ...  17.550000  21.150000
# max     8.600000  17.400000   0.857000   1.400000  ...  43.200000  35.700000
#
#              OWS        DWS         WS      WS/48       OBPM       DBPM  \
# count  79.000000  79.000000  79.000000  79.000000  79.000000  79.000000
# mean    1.217722   1.239241   2.460759   0.097392  -2.418987   0.950633
# std     1.431402   0.986371   2.240674   0.114917   3.832823   2.003578
# min    -1.000000   0.000000  -0.300000  -0.738000 -28.000000  -5.700000
# 25%     0.200000   0.300000   0.600000   0.076000  -3.250000  -0.300000
# 50%     0.800000   1.200000   2.100000   0.115000  -1.900000   1.100000
# 75%     1.850000   1.800000   3.650000   0.146000  -0.200000   2.300000
# max     6.100000   4.100000   9.900000   0.231000   2.100000   5.500000
#
#              BPM       VORP
# count  79.000000  79.000000
# mean   -1.470886   0.513924
# std     4.727881   0.926495
# min   -28.800000  -0.600000
# 25%    -2.700000  -0.100000
# 50%    -0.900000   0.200000
# 75%     0.750000   0.700000
# max     5.800000   3.600000
#
# [8 rows x 47 columns]

# %%
nba_df_G['fg'].mean()
# Out:
# 3.2

# %%
nba_df_F['fg'].mean()
# Out:
# 2.8467336683417086

# %%
nba_df_C['fg'].mean()
# Out:
# 2.9898734177215194

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
